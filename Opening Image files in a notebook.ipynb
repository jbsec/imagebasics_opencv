# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
# only for notebook

# %%
import cv2

# %%
img = cv2.imread('puppy.jpg')
# watch out for wrong file path

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (270, 360, 3)

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('puppy.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (270, 360)

# %%
img_gray.max()
# Out:
# 255

# %%
plt.imshow(img_gray,cmap='gray')

# %%
img
# Out:
# array([[[ 61, 189, 178],
#         [ 61, 189, 178],
#         [ 61, 189, 178],
#         ...,
#         [ 41, 177, 165],
#         [ 43, 177, 165],
#         [ 43, 177, 165]],
#
#        [[ 61, 189, 178],
#         [ 61, 189, 178],
#         [ 61, 189, 178],
#         ...,
#         [ 41, 177, 165],
#         [ 43, 177, 165],
#         [ 43, 177, 165]],
#
#        [[ 61, 189, 178],
#         [ 61, 189, 178],
#         [ 61, 189, 178],
#         ...,
#         [ 43, 177, 165],
#         [ 45, 176, 165],
#         [ 45, 176, 165]],
#
#        ...,
#
#        [[ 69, 175, 169],
#         [ 72, 178, 171],
#         [ 68, 173, 162],
#         ...,
#         [  4, 153, 139],
#         [  3, 154, 139],
#         [ 24, 177, 162]],
#
#        [[ 63, 173, 167],
#         [ 70, 176, 169],
#         [ 70, 172, 161],
#         ...,
#         [  4, 163, 147],
#         [  0, 152, 137],
#         [ 22, 169, 155]],
#
#        [[ 54, 175, 167],
#         [ 63, 175, 167],
#         [ 65, 167, 156],
# ...

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (270, 360, 3)

# %%
new_img = cv2.resize(fix_img,(250,350))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.5
h_ratio = 0.5 # 20% of original height

# %%
new_img = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (135, 180, 3)

# %%
260*5
# Out:
# 1300

# %%
new_img = cv2.flip(fix_img,0)
plt.imshow(new_img)

# %%
new_img = cv2.flip(fix_img,1)
plt.imshow(new_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('totally_new.jpg',fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(2,2))
ax = fig.add_subplot(111)
ax.imshow(fix_img)

# %%
fig = plt.figure(figsize=(2,2))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
# adjust for 2,2 for size
